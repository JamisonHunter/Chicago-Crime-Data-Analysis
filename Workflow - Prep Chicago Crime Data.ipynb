# %% [markdown]
# # Prepare Chicago Crime Data for a GitHub Repository

# %% [markdown]
# - Original Notebook Source: https://github.com/coding-dojo-data-science/preparing-chicago-crime-data
# - Updated 11/17/22

# %% [markdown]
# >- This notebook will process a "Crimes - 2001 to Preset.csv" crime file in your Downloads folder and save it as smaller .csv's in a new "Data/Chicago/" folder inside this notebook's folder/repo.

# %% [markdown]
# # INSTRUCTIONS

# %% [markdown]
# - 1) Go to the Chicago Data Portal's page for ["Crimes - 2001 to Preset"](https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-Present/ijzp-q8t2).
#
# - 2) Click on the Export button on the top right and select CSV.
#     - Save the file to your Downloads folder instead of your repository. **The file is too big for a repository.**
#
#
#
# - 3) Wait for the full file to download.
#     - It is very large (over >1.7GB and may take several minutes to fully download.)
#
#
# - 4) Once the download is complete, change `RAW_FILE` variable below to match the filepath to the downloaded file.

# %% [markdown]
# ## 🚨 Set the correct `RAW_FILE` path

# %% [markdown]
# - The cell below will attempt to check your Downloads folder for any file with a name that contains "Crimes_-_2001_to_Present".
#     - If you know the file path already, you can skip the next cell and just manually set the RAW_FILE variable in the following code cell.

# %%
## Run the cell below to attempt to programmatically find your crime file
import os,glob

## Getting the home folder from environment variables
home_folder = os.environ['HOME']
# print("- Your Home Folder is: " + home_folder)

## Check for downloads folder
if 'Downloads' in os.listdir(home_folder):
    
    
    # Print the Downloads folder path
    dl_folder = os.path.abspath(os.path.join(home_folder,'Downloads'))
    print(f"- Your Downloads folder is '{dl_folder}/'\n")
    
    ## checking for crime files using glob
    crime_files = sorted(glob.glob(dl_folder+'/**/Crimes_-_2001_to_Present*',recursive=True))
    
    # If more than 
    if len(crime_files)==1:
        RAW_FILE = crime_files[0]
        
    elif len(crime_files)>1:
        print('[i] The following files were found:')
        
        for i, fname in enumerate(crime_files):
            print(f"\tcrime_files[{i}] = '{fname}'")
        print(f'\n- Please fill in the RAW_FILE variable in the code cell below with the correct filepath.')

else:
    print(f'[!] Could not programmatically find your downloads folder.')
    print('- Try using Finder (on Mac) or File Explorer (Windows) to navigate to your Downloads folder.')
# Out:
# - Your Downloads folder is 'C:\Users\Jamison\Downloads/'

# %% [markdown]
# <span style="color:red"> **IF THE CODE ABOVE DID NOT FIND YOUR DOWNLOADED FILE, UNCOMMENT AND CHANGE THE `"YOUR FILEPATH HERE"` VARIABLE ONLY IN THE CELL BELOW**

# %%
## (Required) MAKE SURE TO CHANGE THIS VARIABLE TO MATCH YOUR LOCAL FILE NAME
##RAW_FILE = r"YOUR FILEPATH HERE")

# %% [markdown]
# <span style="color:red"> **DO NOT CHANGE ANYTHING IN THE CELL BELOW**

# %%
## DO NOT CHANGE THIS CELL
if RAW_FILE == r"YOUR FILEPATH HERE":
	raise Exception("You must update the RAW_FILE variable in the previous cell to match your local filepath.")
	
RAW_FILE
# Out:
# 'C:\\Users\\Jamison\\Downloads\\Crimes_-_2001_to_Present.csv'

# %%
## (Optional) SET THE FOLDER FOR FINAL FILES
OUTPUT_FOLDER = 'Data/Chicago/'
os.makedirs(OUTPUT_FOLDER, exist_ok=True)

# %% [markdown]
# # 🔄 Full Workflow

# %% [markdown]
# - Now that your RAW_FILE variable is set either:
#     - On the toolbar, click on the Kernel menu > "Restart and Run All".
#     - OR click on this cell first, then on the toolbar click on the "Cell" menu > "Run All Below"

# %%
import pandas as pd

chicago_full = pd.read_csv(RAW_FILE)
chicago_full
# Out:
#                ID Case Number                    Date                   Block  \
# 0        11646166    JC213529  09/01/2018 12:01:00 AM   082XX S INGLESIDE AVE
# 1        11645836    JC212333  05/01/2016 12:25:00 AM     055XX S ROCKWELL ST
# 2        11243268    JB167760  01/01/2017 12:01:00 AM        047XX N CLARK ST
# 3         1896258     G749215  12/15/2001 02:00:00 AM        011XX N STATE ST
# 4        11645527    JC212744  02/02/2015 10:00:00 AM      069XX W ARCHER AVE
# ...           ...         ...                     ...                     ...
# 7861698  13128007    JG325985  06/21/2023 08:00:00 PM  031XX N CALIFORNIA AVE
# 7861699  13128066    JG325838  06/06/2023 03:42:00 PM    018XX N LOCKWOOD AVE
# 7861700  13129823    JG328250  06/28/2023 06:00:00 PM      059XX S KEELER AVE
# 7861701  13128324    JG326502  05/13/2023 12:00:00 PM       020XX W CERMAK RD
# 7861702  13129172    JG327619  06/20/2023 04:00:00 AM   028XX N MAPLEWOOD AVE
#
#          IUCR                Primary Type  \
# 0        0810                       THEFT
# 1        1153          DECEPTIVE PRACTICE
# 2        1562                 SEX OFFENSE
# 3        0460                     BATTERY
# 4        1153          DECEPTIVE PRACTICE
# ...       ...                         ...
# 7861698  1320             CRIMINAL DAMAGE
# 7861699  1752  OFFENSE INVOLVING CHILDREN
# 7861700  0810                       THEFT
# 7861701  1120          DECEPTIVE PRACTICE
# 7861702  0460                     BATTERY
#
#                                                Description  \
# 0                                                OVER $500
# 1                      FINANCIAL IDENTITY THEFT OVER $ 300
# 2                                AGG CRIMINAL SEXUAL ABUSE
# 3                                                   SIMPLE
# 4                      FINANCIAL IDENTITY THEFT OVER $ 300
# ...                                                    ...
# 7861698                                         TO VEHICLE
# 7861699  AGGRAVATED CRIMINAL SEXUAL ABUSE BY FAMILY MEMBER
# 7861700                                          OVER $500
# 7861701                                            FORGERY
# 7861702                                             SIMPLE
#
#         Location Description  Arrest  Domestic  ...  Ward  Community Area  \
# 0                  RESIDENCE   False      True  ...   8.0            44.0
# 1                        NaN   False     False  ...  15.0            63.0
# 2                  APARTMENT   False     False  ...  47.0             3.0
# 3                     STREET   False     False  ...   NaN             NaN
# 4                      OTHER   False     False  ...  23.0            56.0
# ...                      ...     ...       ...  ...   ...             ...
# 7861698               STREET   False     False  ...  35.0            21.0
# 7861699            APARTMENT   False     False  ...  37.0            25.0
# 7861700               STREET   False     False  ...  13.0            65.0
# 7861701    CURRENCY EXCHANGE   False     False  ...  25.0            31.0
# 7861702            RESIDENCE   False      True  ...  35.0            21.0
#
#          FBI Code  X Coordinate Y Coordinate  Year              Updated On  \
# 0              06           NaN          NaN  2018  04/06/2019 04:04:43 PM
# 1              11           NaN          NaN  2016  04/06/2019 04:04:43 PM
# 2              17           NaN          NaN  2017  09/13/2018 03:56:52 PM
# 3             08B           NaN          NaN  2001  08/17/2015 03:03:40 PM
# 4              11           NaN          NaN  2015  04/06/2019 04:04:43 PM
# ...           ...           ...          ...   ...                     ...
# 7861698        14     1157169.0    1920611.0  2023  08/05/2023 04:45:54 PM
# 7861699        17     1140792.0    1911954.0  2023  08/05/2023 04:45:54 PM
# 7861700        06     1149387.0    1864869.0  2023  08/05/2023 04:45:54 PM
# 7861701        10     1163211.0    1889404.0  2023  08/05/2023 04:45:54 PM
# 7861702       08B     1158868.0    1918755.0  2023  08/05/2023 04:45:54 PM
#
#           Latitude  Longitude                       Location
# 0              NaN        NaN                            NaN
# 1              NaN        NaN                            NaN
# 2              NaN        NaN                            NaN
# 3              NaN        NaN                            NaN
# 4              NaN        NaN                            NaN
# ...            ...        ...                            ...
# 7861698  41.937926 -87.697782  (41.937925817, -87.697782474)
# 7861699  41.914487 -87.758185  (41.914487492, -87.758185241)
# 7861700  41.785118 -87.727828  (41.785117789, -87.727827896)
# 7861701  41.852166 -87.676455   (41.85216632, -87.676455032)
# 7861702  41.932798 -87.691589  (41.932798095, -87.691589364)
#
# [7861703 rows x 22 columns]

# %%
# this cell can take up to 1 min to run
date_format = "%m/%d/%Y %H:%M:%S %p"

chicago_full['Datetime'] = pd.to_datetime(chicago_full['Date'], format=date_format)
chicago_full = chicago_full.sort_values('Datetime')
chicago_full
# Out:
#                ID Case Number                    Date                 Block  \
# 2417570   1584605     G351833  01/01/2001 01:00:00 AM   024XX W CORTLAND ST
# 2212702   1311626     G001009  01/01/2001 01:00:00 AM       023XX S TROY ST
# 2212373   1310610     G000911  01/01/2001 01:00:00 AM   022XX W CORNELIA AV
# 2212369   1310586     G000876  01/01/2001 01:00:00 AM  052XX S FAIRFIELD AV
# 2214150   1315701     G003835  01/01/2001 01:00:00 PM    011XX S PULASKI RD
# ...           ...         ...                     ...                   ...
# 307441   13161973    JG366256  08/02/2023 12:55:00 PM    082XX S CICERO AVE
# 307200   13161374    JG365619  08/02/2023 12:55:00 AM  035XX S MICHIGAN AVE
# 307665   13162035    JG366227  08/02/2023 12:55:00 PM    120XX S HALSTED ST
# 307747   13162553    JG366237  08/02/2023 12:57:00 PM  073XX S PHILLIPS AVE
# 307542   13161434    JG365620  08/02/2023 12:59:00 AM   054XX N SHERIDAN RD
#
#          IUCR     Primary Type              Description Location Description  \
# 2417570  2825    OTHER OFFENSE  HARASSMENT BY TELEPHONE            RESIDENCE
# 2212702  1320  CRIMINAL DAMAGE               TO VEHICLE               STREET
# 2212373  1320  CRIMINAL DAMAGE               TO VEHICLE               STREET
# 2212369  0820            THEFT           $500 AND UNDER               STREET
# 2214150  041A          BATTERY      AGGRAVATED: HANDGUN            RESIDENCE
# ...       ...              ...                      ...                  ...
# 307441   0325          ROBBERY      VEHICULAR HIJACKING      OTHER (SPECIFY)
# 307200   0460          BATTERY                   SIMPLE      OTHER (SPECIFY)
# 307665   0560          ASSAULT                   SIMPLE             SIDEWALK
# 307747   0560          ASSAULT                   SIMPLE            APARTMENT
# 307542   0560          ASSAULT                   SIMPLE             SIDEWALK
#
#          Arrest  Domestic  ...  Community Area  FBI Code  X Coordinate  \
# 2417570   False     False  ...             NaN        26     1159701.0
# 2212702   False     False  ...             NaN        14     1155692.0
# 2212373   False     False  ...             NaN        14     1160786.0
# 2212369   False     False  ...             NaN        06     1158889.0
# 2214150   False     False  ...             NaN       04B     1149936.0
# ...         ...       ...  ...             ...       ...           ...
# 307441    False     False  ...            70.0        03     1145865.0
# 307200    False     False  ...            35.0       08B     1177773.0
# 307665    False      True  ...            53.0       08A     1173161.0
# 307747    False     False  ...            43.0       08A     1193921.0
# 307542    False     False  ...            77.0       08A     1168655.0
#
#          Y Coordinate  Year              Updated On   Latitude  Longitude  \
# 2417570     1912508.0  2001  08/17/2015 03:03:40 PM  41.915639 -87.688701
# 2212702     1888116.0  2001  08/17/2015 03:03:40 PM  41.848786 -87.704087
# 2212373     1923163.0  2001  08/17/2015 03:03:40 PM  41.944854 -87.684418
# 2212369     1869741.0  2001  08/17/2015 03:03:40 PM  41.798298 -87.692856
# 2214150     1894501.0  2001  08/17/2015 03:03:40 PM  41.866421 -87.725046
# ...               ...   ...                     ...        ...        ...
# 307441      1849387.0  2023  08/09/2023 04:52:01 PM  41.742700 -87.741132
# 307200      1881628.0  2023  08/09/2023 04:52:01 PM  41.830510 -87.623245
# 307665      1825111.0  2023  08/09/2023 04:52:01 PM  41.675524 -87.641833
# 307747      1856728.0  2023  08/09/2023 04:52:01 PM  41.761802 -87.564815
# 307542      1936367.0  2023  08/09/2023 04:52:01 PM  41.980919 -87.655111
#
#                               Location            Datetime
# 2417570  (41.915638736, -87.688700749) 2001-01-01 01:00:00
# 2212702  (41.848786421, -87.704086603) 2001-01-01 01:00:00
# 2212373  (41.944854306, -87.684418276) 2001-01-01 01:00:00
# 2212369  (41.798298315, -87.692856014) 2001-01-01 01:00:00
# 2214150   (41.866421432, -87.72504577) 2001-01-01 01:00:00
# ...                                ...                 ...
# 307441   (41.742699815, -87.741132091) 2023-08-02 12:55:00
# 307200   (41.830510293, -87.623244822) 2023-08-02 12:55:00
# 307665   (41.675523891, -87.641832941) 2023-08-02 12:55:00
# 307747   (41.761801683, -87.564815112) 2023-08-02 12:57:00
# 307542   (41.980919411, -87.655110993) 2023-08-02 12:59:00
#
# [7861703 rows x 23 columns]

# %% [markdown]
# ## Separate the Full Dataset by Years

# %%
chicago_full['Datetime'].dt.year
# Out:
# 2417570    2001
# 2212702    2001
# 2212373    2001
# 2212369    2001
# 2214150    2001
#            ...
# 307441     2023
# 307200     2023
# 307665     2023
# 307747     2023
# 307542     2023
# Name: Datetime, Length: 7861703, dtype: int64

# %%
# save the years for every crime
chicago_full["Year"] = chicago_full['Datetime'].dt.year.astype(str)
chicago_full["Year"].value_counts()
# Out:
# 2002    486807
# 2001    485886
# 2003    475984
# 2004    469421
# 2005    453772
# 2006    448179
# 2007    437087
# 2008    427169
# 2009    392825
# 2010    370505
# 2011    351977
# 2012    336275
# 2013    307479
# 2014    275750
# 2016    269816
# 2017    269100
# 2018    268820
# 2015    264780
# 2019    261296
# 2022    238760
# 2020    212185
# 2021    208776
# 2023    149054
# Name: Year, dtype: int64

# %%
## Dropping unneeded columns to reduce file size
drop_cols = ["X Coordinate","Y Coordinate", "Community Area","FBI Code",
             "Case Number","Updated On",'Block','Location','IUCR']

# %%
# save final df
chicago_final = chicago_full.drop(columns=drop_cols)
chicago_final = chicago_final.set_index('Datetime')
chicago_final
# Out:
#                            ID                    Date     Primary Type  \
# Datetime
# 2001-01-01 01:00:00   1584605  01/01/2001 01:00:00 AM    OTHER OFFENSE
# 2001-01-01 01:00:00   1311626  01/01/2001 01:00:00 AM  CRIMINAL DAMAGE
# 2001-01-01 01:00:00   1310610  01/01/2001 01:00:00 AM  CRIMINAL DAMAGE
# 2001-01-01 01:00:00   1310586  01/01/2001 01:00:00 AM            THEFT
# 2001-01-01 01:00:00   1315701  01/01/2001 01:00:00 PM          BATTERY
# ...                       ...                     ...              ...
# 2023-08-02 12:55:00  13161973  08/02/2023 12:55:00 PM          ROBBERY
# 2023-08-02 12:55:00  13161374  08/02/2023 12:55:00 AM          BATTERY
# 2023-08-02 12:55:00  13162035  08/02/2023 12:55:00 PM          ASSAULT
# 2023-08-02 12:57:00  13162553  08/02/2023 12:57:00 PM          ASSAULT
# 2023-08-02 12:59:00  13161434  08/02/2023 12:59:00 AM          ASSAULT
#
#                                  Description Location Description  Arrest  \
# Datetime
# 2001-01-01 01:00:00  HARASSMENT BY TELEPHONE            RESIDENCE   False
# 2001-01-01 01:00:00               TO VEHICLE               STREET   False
# 2001-01-01 01:00:00               TO VEHICLE               STREET   False
# 2001-01-01 01:00:00           $500 AND UNDER               STREET   False
# 2001-01-01 01:00:00      AGGRAVATED: HANDGUN            RESIDENCE   False
# ...                                      ...                  ...     ...
# 2023-08-02 12:55:00      VEHICULAR HIJACKING      OTHER (SPECIFY)   False
# 2023-08-02 12:55:00                   SIMPLE      OTHER (SPECIFY)   False
# 2023-08-02 12:55:00                   SIMPLE             SIDEWALK   False
# 2023-08-02 12:57:00                   SIMPLE            APARTMENT   False
# 2023-08-02 12:59:00                   SIMPLE             SIDEWALK   False
#
#                      Domestic  Beat  District  Ward  Year   Latitude  \
# Datetime
# 2001-01-01 01:00:00     False  1434      14.0   NaN  2001  41.915639
# 2001-01-01 01:00:00     False  1033      10.0   NaN  2001  41.848786
# 2001-01-01 01:00:00     False  1913      19.0   NaN  2001  41.944854
# 2001-01-01 01:00:00     False   911       9.0   NaN  2001  41.798298
# 2001-01-01 01:00:00     False  1132      11.0   NaN  2001  41.866421
# ...                       ...   ...       ...   ...   ...        ...
# 2023-08-02 12:55:00     False   834       8.0  18.0  2023  41.742700
# 2023-08-02 12:55:00     False   212       2.0   3.0  2023  41.830510
# 2023-08-02 12:55:00      True   523       5.0  21.0  2023  41.675524
# 2023-08-02 12:57:00     False   334       3.0   7.0  2023  41.761802
# 2023-08-02 12:59:00     False  2023      20.0  48.0  2023  41.980919
#
#                      Longitude
# Datetime
# 2001-01-01 01:00:00 -87.688701
# 2001-01-01 01:00:00 -87.704087
# 2001-01-01 01:00:00 -87.684418
# 2001-01-01 01:00:00 -87.692856
# 2001-01-01 01:00:00 -87.725046
# ...                        ...
# 2023-08-02 12:55:00 -87.741132
# 2023-08-02 12:55:00 -87.623245
# 2023-08-02 12:55:00 -87.641833
# 2023-08-02 12:57:00 -87.564815
# 2023-08-02 12:59:00 -87.655111
#
# [7861703 rows x 13 columns]

# %%
# unique # of year bins
year_bins = chicago_final['Year'].astype(str).unique()
year_bins
# Out:
# array(['2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
#        '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018', '2019', '2020', '2021', '2022', '2023'],
#       dtype=object)

# %%
FINAL_DROP = ['Year']

# %%
## set save location 

os.makedirs(OUTPUT_FOLDER, exist_ok=True)
print(f"[i] Saving .csv's to {OUTPUT_FOLDER}")
## loop through years
for year in year_bins:
    
    ## save temp slices of dfs to save.
    temp_df = chicago_final.loc[year]
    temp_df = temp_df.sort_index()
    temp_df = temp_df.reset_index(drop=True)
    temp_df = temp_df.drop(columns=FINAL_DROP)

    # save as csv to output folder
    fname_temp = f"{OUTPUT_FOLDER}Chicago-Crime_{year}.csv"#.gz
    temp_df.to_csv(fname_temp,index=False)

    print(f"- Succesfully saved {fname_temp}")
# Out:
# [i] Saving .csv's to Data/Chicago/
# - Succesfully saved Data/Chicago/Chicago-Crime_2001.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2002.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2003.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2004.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2005.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2006.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2007.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2008.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2009.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2010.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2011.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2012.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2013.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2014.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2015.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2016.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2017.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2018.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2019.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2020.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2021.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2022.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2023.csv

# %%
saved_files = sorted(glob.glob(OUTPUT_FOLDER+'*.*csv'))
saved_files
# Out:
# ['Data/Chicago\\Chicago-Crime_2001.csv',
#  'Data/Chicago\\Chicago-Crime_2002.csv',
#  'Data/Chicago\\Chicago-Crime_2003.csv',
#  'Data/Chicago\\Chicago-Crime_2004.csv',
#  'Data/Chicago\\Chicago-Crime_2005.csv',
#  'Data/Chicago\\Chicago-Crime_2006.csv',
#  'Data/Chicago\\Chicago-Crime_2007.csv',
#  'Data/Chicago\\Chicago-Crime_2008.csv',
#  'Data/Chicago\\Chicago-Crime_2009.csv',
#  'Data/Chicago\\Chicago-Crime_2010.csv',
#  'Data/Chicago\\Chicago-Crime_2011.csv',
#  'Data/Chicago\\Chicago-Crime_2012.csv',
#  'Data/Chicago\\Chicago-Crime_2013.csv',
#  'Data/Chicago\\Chicago-Crime_2014.csv',
#  'Data/Chicago\\Chicago-Crime_2015.csv',
#  'Data/Chicago\\Chicago-Crime_2016.csv',
#  'Data/Chicago\\Chicago-Crime_2017.csv',
#  'Data/Chicago\\Chicago-Crime_2018.csv',
#  'Data/Chicago\\Chicago-Crime_2019.csv',
#  'Data/Chicago\\Chicago-Crime_2020.csv',
#  'Data/Chicago\\Chicago-Crime_2021.csv',
#  'Data/Chicago\\Chicago-Crime_2022.csv',
#  'Data/Chicago\\Chicago-Crime_2023.csv']

# %%
## create a README.txt for the zip files
readme = """Source URL: 
- https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-Present/ijzp-q8t2
- Filtered for years 2000-Present.

Downloaded 07/18/2022
- Files are split into 1 year per file.

EXAMPLE USAGE:
>> import glob
>> import pandas as pd
>> folder = "Data/Chicago/"
>> crime_files = sorted(glob.glob(folder+"*.csv"))
>> df = pd.concat([pd.read_csv(f) for f in crime_files])
"""
print(readme)


with open(f"{OUTPUT_FOLDER}README.txt",'w') as f:
    f.write(readme)
# Out:
# Source URL:
# - https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-Present/ijzp-q8t2
# - Filtered for years 2000-Present.
#
# Downloaded 07/18/2022
# - Files are split into 1 year per file.
#
# EXAMPLE USAGE:
# >> import glob
# >> import pandas as pd
# >> folder = "Data/Chicago/"
# >> crime_files = sorted(glob.glob(folder+"*.csv"))
# >> df = pd.concat([pd.read_csv(f) for f in crime_files])

# %% [markdown]
# ## Confirmation

# %% [markdown]
# - Follow the example usage above to test if your files were created successfully.

# %%
# get list of files from folder
crime_files = sorted(glob.glob(OUTPUT_FOLDER+"*.csv"))
df = pd.concat([pd.read_csv(f, nrows=5) for f in crime_files])
df
# Out:
#           ID                    Date     Primary Type  \
# 0    1584605  01/01/2001 01:00:00 AM    OTHER OFFENSE
# 1    1311626  01/01/2001 01:00:00 AM  CRIMINAL DAMAGE
# 2    1310610  01/01/2001 01:00:00 AM  CRIMINAL DAMAGE
# 3    1310586  01/01/2001 01:00:00 AM            THEFT
# 4    1315701  01/01/2001 01:00:00 PM          BATTERY
# ..       ...                     ...              ...
# 0   12939417  01/01/2023 01:00:00 AM  CRIMINAL DAMAGE
# 1   12939189  01/01/2023 01:00:00 AM    OTHER OFFENSE
# 2   12940914  01/01/2023 01:00:00 AM  CRIMINAL DAMAGE
# 3   12939172  01/01/2023 01:00:00 AM  CRIMINAL DAMAGE
# 4   12939140  01/01/2023 01:00:00 AM            THEFT
#
#                 Description Location Description  Arrest  Domestic  Beat  \
# 0   HARASSMENT BY TELEPHONE            RESIDENCE   False     False  1434
# 1                TO VEHICLE               STREET   False     False  1033
# 2                TO VEHICLE               STREET   False     False  1913
# 3            $500 AND UNDER               STREET   False     False   911
# 4       AGGRAVATED: HANDGUN            RESIDENCE   False     False  1132
# ..                      ...                  ...     ...       ...   ...
# 0                TO VEHICLE               STREET   False     False   734
# 1     OTHER VEHICLE OFFENSE               STREET   False      True   423
# 2                TO VEHICLE               STREET   False      True   212
# 3               TO PROPERTY            APARTMENT   False     False   412
# 4            $500 AND UNDER        BAR OR TAVERN   False     False  1832
#
#     District  Ward   Latitude  Longitude
# 0       14.0   NaN  41.915639 -87.688701
# 1       10.0   NaN  41.848786 -87.704087
# 2       19.0   NaN  41.944854 -87.684418
# 3        9.0   NaN  41.798298 -87.692856
# 4       11.0   NaN  41.866421 -87.725046
# ..       ...   ...        ...        ...
# 0        7.0  17.0  41.760449 -87.657918
# 1        4.0   7.0  41.736726 -87.556955
# 2        2.0   4.0  41.829329 -87.606846
# 3        4.0   8.0  41.740095 -87.578202
# 4       18.0  42.0  41.893542 -87.629702
#
# [115 rows x 12 columns]

# %%
years = df['Date'].map(lambda x: x.split()[0].split('/')[-1])
years.value_counts().sort_index()
# Out:
# 2001    5
# 2002    5
# 2003    5
# 2004    5
# 2005    5
# 2006    5
# 2007    5
# 2008    5
# 2009    5
# 2010    5
# 2011    5
# 2012    5
# 2013    5
# 2014    5
# 2015    5
# 2016    5
# 2017    5
# 2018    5
# 2019    5
# 2020    5
# 2021    5
# 2022    5
# 2023    5
# Name: Date, dtype: int64

# %% [markdown]
# ## Summary

# %% [markdown]
# - The chicago crime dataset has now been saved to your repository as csv files.
# - You should save your notebook, commit your work and push to GitHub using GitHub desktop.
